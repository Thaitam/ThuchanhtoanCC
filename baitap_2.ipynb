# %% [markdown]
# <a href="https://colab.research.google.com/github/Thaitam/ThuchanhtoanCC/blob/main/baitap_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bài tập 1:** Vẽ biểu đồ số ngày mưa trung bình và số giờ nắng trung bình hằng tháng theo số liệu khí hậu của TP.HCM

# %% [markdown]
# bài 1

# %%
from pylab import plot,show
thang = range(1,13)
so_ngay_mua_tb = [3,4,2,5,2,8,9,7,2,11,6,7]
so_ngay_nang_tb = [12,15,16,18,10,14,11,10,9,13,17,12]
plot(thang,so_ngay_mua_tb,so_ngay_nang_tb,marker = 'o')
# Out:
# [<matplotlib.lines.Line2D at 0x7f9987b0d590>,
#  <matplotlib.lines.Line2D at 0x7f9987b0d890>]
