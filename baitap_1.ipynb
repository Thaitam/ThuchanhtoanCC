# %% [markdown]
# <a href="https://colab.research.google.com/github/Thaitam/ThuchanhtoanCC/blob/main/baitap_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ve do thi ham so f = sin(x), x trong khoang -pi/2 den pi/2

# %%
from sympy import Derivative, Symbol, sin
x = Symbol('x') 
f = sin(x)

# %%
f
# Out:
# sin(x)

# %%
from sympy import *
a= -2*pi
b= 2*pi
sympy.plot(f, (x,a,b))

# %% [markdown]
# ve do thi ham so f = abs(x), x trong khoang -2, 2

# %%
from sympy import *
f = abs(x)
sympy.plot(f,(x,-2,2))
